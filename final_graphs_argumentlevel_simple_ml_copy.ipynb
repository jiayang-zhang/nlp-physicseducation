# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots
from matplotlib import rc, rcParams
import pandas as pd

# %%
def four_figures(x_0, y_0, yerr_0, 
                 x_1, y_1, yerr_1,   
                 x_2, y_2, yerr_2, 
                 x_3, y_3, yerr_3, 
                 filepath):
    

    plt.style.use(['science', 'ieee', 'no-latex'])
    plt.rcParams['font.family'] = "Arial"
    rc('font', weight='normal')
# Create a figure with three subplots in a row
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize = (12.5,2.15)) 


    # Plot the first subplot on the left
    axes[0].scatter(x_0, y_0, color = '#A20346', marker = 's', s= 10, label = 'red')
    axes[0].errorbar(x_0, y_0, yerr_0, color='#A20346', fmt='none')
    axes[0].plot(x_0, y_0, linestyle='solid', color='#A20346', alpha=0.5)
    axes[0].set_xlabel('Training ratio', fontsize=10)
    axes[0].set_ylabel('Accuracy', fontsize=10)
    axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
    axes[0].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
    axes[0].minorticks_off()
    axes[0].set_title('(a)')


    # Plot the second subplot in the middle
    axes[1].scatter(x_1, y_1, color = '#004E7E', marker = 's', s= 10, label = 'blue')
    axes[1].errorbar(x_1, y_1, yerr_1, color='#004E7E', fmt='none')
    axes[1].plot(x_1, y_1, linestyle='solid', color='#004E7E', alpha=0.5)
    axes[1].set_xlabel('Training ratio', fontsize=10)
    axes[1].set_ylabel('Accuracy', fontsize=10)
    axes[1].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
    axes[1].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
    axes[1].minorticks_off()
    axes[1].set_title('(b)')
    


    # Plot the third subplot on the right
    axes[2].scatter(x_2, y_2, color = '#3D4E1D', marker = 's', s= 10, label = 'red')
    axes[2].errorbar(x_2, y_2, yerr_2, color='#3D4E1D', fmt='none')
    axes[2].plot(x_2, y_2, linestyle='solid', color='#3D4E1D', alpha=0.5)
    axes[2].set_xlabel('Training ratio', fontsize=10) # , fontweight = 'bold'
    axes[2].set_ylabel('Accuracy', fontsize=10) # fontweight = 'bold'
    axes[2].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
    axes[2].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
    axes[2].minorticks_off()
    axes[2].set_title('(c)')

    # Plot the fourth subplot on the right
    axes[3].scatter(x_3, y_3, color = '#3D4E1D', marker = 's', s= 10, label = 'red')
    axes[3].errorbar(x_3, y_3, yerr_3, color='#3D4E1D', fmt='none', )
    axes[3].plot(x_3, y_3, linestyle='solid', color='#3D4E1D', alpha=0.5)
    axes[3].set_xlabel('Training ratio', fontsize=10) # , fontweight = 'bold'
    axes[3].set_ylabel('Accuracy', fontsize=10) # fontweight = 'bold'
    axes[3].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
    axes[3].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
    axes[3].minorticks_off()
    axes[3].set_title('(d)')



    # Add a shared y-axis label to the leftmost plot
    # fig.text(0.06, 0.5, 'Amplitude', ha='center', va='center', rotation='vertical')
    # Add a shared x-axis label to the bottom plot
    # fig.text(0.5, 0.06, 'Time', ha='center', va='center')

  
 
    # Adjust the spacing between the subplots
    plt.subplots_adjust(wspace=0.3)


    plt.savefig(filepath, dpi = 1000)
    
    # Show the plot
    plt.show()

    return

# %%
#==== BOW ======

xvalue = [0.5,0.6, 0.7, 0.8, 0.9]

#lr 
lr_xval_bow = [0.3146067415730337, 0.2930555555555555, 0.2833333333333333, 0.29444444444444445, 0.3055555555555555]
lr_yerr_bow = [0.01046010490169958, 0.017744229534015554, 0.015382636783181618, 0.022755936532304642, 0.02898606637499727]

#nb 
nb_xval_bow  = [0.3539325842696629, 0.29861111111111105, 0.35370370370370374, 0.3472222222222222, 0.3777777777777778]
nb_yerr_bow  = [0.01256217964887522, 0.02010027161675223, 0.0175573613004048, 0.03395763114980046, 0.044444444444444446]

# svm 
svm_xval_bow = [0.29213483146067415, 0.2847222222222222, 0.3055555555555555, 0.28055555555555556, 0.2611111111111111]
svm_yerr_bow = [0.013812051621412564, 0.010403798636224182, 0.01995460478425261, 0.01627629243633976, 0.027529756939478706]

# rf 
rf_xval_bow = [0.3887640449438202, 0.38472222222222224, 0.37222222222222223, 0.3694444444444444, 0.37777777777777777]
rf_yerr_bow = [0.01851945365554474, 0.016750048625116244, 0.010973079527550111, 0.014958791130929176, 0.03652422763577041]

# %%
# BOW 
filename = 'final_graphs_epistemology/ArgumentLevel_simple_ml_bow'
four_figures(xvalue, lr_xval_bow, lr_yerr_bow, xvalue, nb_xval_bow, nb_yerr_bow, xvalue, svm_xval_bow, svm_yerr_bow, xvalue, rf_xval_bow, rf_yerr_bow, filename)

# %%
# ===== TF-IDF =======

#lr
xvalue = [0.5,0.6, 0.7, 0.8, 0.9]
lr_xval_tf = [0.397752808988764, 0.3847222222222222, 0.3648148148148148, 0.4166666666666667, 0.37222222222222223]
lr_yerr_tf = [0.011985018726591757, 0.015910037293925542, 0.01991637753691565, 0.028688765527462346, 0.02625453125695893]


#nb 
nb_xval_tf = [0.3921348314606742, 0.4, 0.3814814814814815, 0.3694444444444444, 0.37777777777777777]
nb_yerr_tf = [0.01575261486502853, 0.012729376930432888, 0.017503020837972623, 0.018541652217130354, 0.038667801884853886]

#svm
svm_xval_tf = [0.3808988764044944, 0.36944444444444446, 0.42407407407407416, 0.4111111111111111, 0.3555555555555555]
svm_yerr_tf = [0.0204076894768918, 0.013764878469739358, 0.01548140272096846, 0.024074074074074074, 0.03434673516850261]

#rf
rf_xval_tf = [0.3651685393258427, 0.36249999999999993, 0.3555555555555555, 0.3694444444444444, 0.45]
rf_yerr_tf = [0.01851945365554474, 0.016750048625116244, 0.010973079527550111, 0.014958791130929176, 0.03652422763577041]

# %%
filename = 'final_graphs_epistemology/ArgumentLevel_simple_ml_tf'
four_figures(xvalue, lr_xval_tf, lr_yerr_tf, xvalue, nb_xval_tf, nb_yerr_tf, xvalue, svm_xval_tf, svm_yerr_tf, xvalue, rf_xval_tf, rf_yerr_tf, filename)

# %%
plt.style.use(['science', 'ieee', 'no-latex'])
plt.rcParams['font.family'] = "Arial"
rc('font', weight='normal')
# Create a figure with three subplots in a row
fig, axes = plt.subplots(nrows=1, ncols=4, figsize = (12.5,2.15)) 


# Plot the first subplot on the left
axes[0].scatter(xvalue, lr_xval_bow, color = '#004E7E', marker = 's', s= 10, label = 'BOW')
axes[0].errorbar(xvalue, lr_xval_bow, lr_yerr_bow, color='#004E7E', fmt='none')
axes[0].plot(xvalue, lr_xval_bow, linestyle='solid', color='#004E7E', alpha=0.5)

axes[0].scatter(xvalue, lr_xval_tf, color = '#3D4E1D', marker = 's', s= 10, label = 'TF-IDF')
axes[0].errorbar(xvalue, lr_xval_bow, lr_yerr_tf, color='#3D4E1D', fmt='none')
axes[0].plot(xvalue, lr_xval_tf, linestyle='solid', color='#3D4E1D', alpha=0.5)

axes[0].set_xlabel('Training ratio', fontsize=10)
axes[0].set_ylabel('Accuracy', fontsize=10)
axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[0].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
axes[0].minorticks_off()
axes[0].set_title('(e)')
legend = axes[0].legend( loc='upper left', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 7})
legend.get_frame().set_linewidth(0.2)


# Plot the second subplot in the middle
axes[1].scatter(xvalue, nb_xval_bow, color = '#004E7E', marker = 's', s= 10, label = 'BOW')
axes[1].errorbar(xvalue, nb_xval_bow, nb_yerr_bow, color='#004E7E', fmt='none')
axes[1].plot(xvalue, nb_xval_bow, linestyle='solid', color='#004E7E', alpha=0.5)

axes[1].scatter(xvalue, nb_xval_tf, color = '#3D4E1D', marker = 's', s= 10, label = 'TF-IDF')
axes[1].errorbar(xvalue, nb_xval_tf, nb_yerr_tf, color='#3D4E1D', fmt='none')
axes[1].plot(xvalue, nb_xval_tf, linestyle='solid', color='#3D4E1D', alpha=0.5)

axes[1].set_xlabel('Training ratio', fontsize=10)
axes[1].set_ylabel('Accuracy', fontsize=10)
axes[1].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[1].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
axes[1].minorticks_off()
axes[1].set_title('(f)')

legend = axes[1].legend( loc='upper left', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 7})
legend.get_frame().set_linewidth(0.2)

# Plot the third subplot on the right
axes[2].scatter(xvalue, svm_xval_bow, color = '#004E7E', marker = 's', s= 10, label = 'BOW')
axes[2].errorbar(xvalue, svm_xval_bow, svm_yerr_bow, color='#004E7E', fmt='none')
axes[2].plot(xvalue, svm_xval_bow, linestyle='solid', color='#004E7E', alpha=0.5)

axes[2].scatter(xvalue, svm_xval_tf, color = '#3D4E1D', marker = 's', s= 10, label = 'TF-IDF')
axes[2].errorbar(xvalue, svm_xval_tf, svm_yerr_tf, color='#3D4E1D', fmt='none')
axes[2].plot(xvalue, svm_xval_tf, linestyle='solid', color='#3D4E1D', alpha=0.5)

axes[2].set_xlabel('Training ratio', fontsize=10) # , fontweight = 'bold'
axes[2].set_ylabel('Accuracy', fontsize=10) # fontweight = 'bold'
axes[2].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[2].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
axes[2].minorticks_off()
axes[2].set_title('(g)')
legend = axes[2].legend( loc='upper left', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 7})
legend.get_frame().set_linewidth(0.2)


# Plot the fourth subplot on the right
axes[3].scatter(xvalue, rf_xval_bow, color = '#004E7E', marker = 's', s= 10, label = 'BOW')
axes[3].errorbar(xvalue, rf_xval_bow, rf_yerr_bow, color='#004E7E', fmt='none', )
axes[3].plot(xvalue, rf_xval_bow, linestyle='solid', color='#004E7E', alpha=0.5)

axes[3].scatter(xvalue, rf_xval_tf, color = '#3D4E1D', marker = 's', s= 10, label = 'TF-IDF')
axes[3].errorbar(xvalue, rf_xval_tf, rf_yerr_tf, color='#3D4E1D', fmt='none', )
axes[3].plot(xvalue, rf_xval_tf, linestyle='solid', color='#3D4E1D', alpha=0.5)

axes[3].set_xlabel('Training ratio', fontsize=10) # , fontweight = 'bold'
axes[3].set_ylabel('Accuracy', fontsize=10) # fontweight = 'bold'
axes[3].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[3].yaxis.set_ticks(np.arange(0.2, 0.8, 0.1))
axes[3].minorticks_off()
axes[3].set_title('(h)')
legend = axes[3].legend( loc='upper left', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 7})
legend.get_frame().set_linewidth(0.2)



# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.3)

filepath = 'Final-graphs/Argumentlevel_final_efia'
plt.savefig(filepath, dpi = 1000)

# Show the plot
plt.show()
