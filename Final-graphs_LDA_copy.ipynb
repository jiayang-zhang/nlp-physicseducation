# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt#

import scienceplots
from matplotlib import rc, rcParams

# %%
#Y1
dir_csv_y1 = 'outputs/LDA_weights_grades_df_year1.csv'
df_y1     = pd.read_csv(dir_csv_y1, encoding='utf-8')

#Y2
dir_csv_y2 = 'outputs/LDA_weights_grades_df_year2.csv'
df_y2      = pd.read_csv(dir_csv_y2, encoding='utf-8')

#Y1Y2
dir_csv_y1y2 = 'outputs/labels_cleaned_y1y2.csv'
df_y1y2      = pd.read_csv(dir_csv_y1y2, encoding='utf-8')

#Y1Y2 
file_name_y1y2 = 'outputs/LDA_weights_df_year1_year2.csv'
df_y1y2_weight = pd.read_csv(file_name_y1y2, encoding='utf-8')

num_topics = 2

# %%
plt.style.use(['science', 'ieee', 'no-latex'])
plt.rcParams['font.family'] = "Arial"
rc('font', weight='normal')

# %%
print('year1 length', len(df_y1))
print('year2 length', len(df_y2))
# Out:
# year1 length 79
# year2 length 70

# %% [markdown]
# # YEAR 1

# %% [markdown]
# ### Below are the heatmap and scatter plots helping us to identify plots specific to this year.

# %%
topic_0_y1 = []
topic_1_y1 = []
index1= []
for i in range(79):
    topic_0_y1.append(df_y1.iloc[i][6])
    topic_1_y1.append(df_y1.iloc[i][7])
    index1.append(i)


# # sorted weights
# sorted_topic_0_y1 = sorted(topic_0_y1)
# sorted_topic_1_y1 = sorted(topic_1_y1)

# print('sorted', sorted_topic_0_y2)
# print('unsorted', topic_0_y2)

# %%
x_0 = index1
#y_0 = sorted_topic_0_y1
y_0 = topic_0_y1

x_1 = index1
y_1 = topic_1_y1

fig, axes = plt.subplots(nrows=1, ncols=2, figsize= (6,2)) 
#fig.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)

# Plot the first subplot on the left
axes[0].scatter(x_0, y_0, color = '#A20346', marker = '^', s= 10, label = 'Topic 0')
#axes[0].errorbar(x_0, y_0, yerr_0, color='#A20346', fmt='none')
#axes[0].plot(x_0, y_0, linestyle='solid', color='#A20346', alpha=0.5)
axes[0].set_xlabel('Arbitrary Document number', fontsize=10)
axes[0].set_ylabel('Topic weight', fontsize=10)
#axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[0].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[0].minorticks_off()
axes[0].set_title('(a)')
legend = axes[0].legend(loc='upper left', framealpha=1, frameon=True, edgecolor = 'black')
legend.get_frame().set_linewidth(0.2)



# Plot the second subplot in the middle
axes[1].scatter(x_1, y_1, color = '#004E7E', marker = 'D', s= 10, label = 'Topic 1')
#axes[1].errorbar(x_1, y_1, yerr_1, color='#004E7E', fmt='none')
#axes[1].plot(x_1, y_1, linestyle='solid', color='#004E7E', alpha=0.5)
axes[1].set_xlabel('Arbitrary Document number', fontsize=10)
axes[1].set_ylabel('Topic weight', fontsize=10)
#axes[1].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[1].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[1].minorticks_off()
axes[1].set_title('(b)')
legend = axes[1].legend(loc='upper right', framealpha=1, frameon=True, edgecolor = 'black')
legend.get_frame().set_linewidth(0.2)

filepath = 'Final-graphs-LDA/Y1_sorted_topic_weights'
plt.savefig(filepath, dpi = 1000)

# %%
# x = np.linspace(0,1,1)
# #plt.figure(figsize=(5, 5))
# #plt.vlines(x=93, ymin=0, ymax=len(x), colors='green', lw=1, label='partition')
# plt.scatter(index1, sorted_topic_0_y1 , color = '#A20346', label='Topic_0 - Year 1',  marker= '^', s = 6)
# plt.scatter(index1, topic_1_y1 ,  color = '#004E7E', label='Topic_1 - Year 2',  marker= 's', s = 6)
# plt.xlabel("Document number")
# plt.ylabel("Topic weight")
# plt.legend( prop = {'size' : 7})
# plt.title('Weights of %d in all documents - YEAR1' % num_topics)
# # single vline with full ymin and ymax
# #plt.vlines(x=95, ymin=0, ymax=len(x), colors='green', ls=':', lw=2, label='vline_single - full height')
# plt.show()

# %% [markdown]
# # YEAR 2

# %% [markdown]
# ### Below are the heatmap and scatter plots helping us to identify plots specific to this year.

# %%
df_y2.sort_values(by='0', ascending=True)
topic_0_y2 = []
topic_1_y2 = []
index = []
for i in range(70):
    topic_0_y2.append(df_y2.iloc[i][6])
    topic_1_y2.append(df_y2.iloc[i][7])
    index.append(i)


# # sorted weights
# sorted_topic_0_y2 = sorted(topic_0_y2)
# sorted_topic_1_y2 = sorted(topic_1_y2, reverse=True)

# %%
x_0 = index
y_0 = topic_0_y2

x_1 = index
#y_1 = topic_1_y2
y_1 = topic_1_y2

fig, axes = plt.subplots(nrows=1, ncols=2, figsize= (6,2)) 
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)

# Plot the first subplot on the left
axes[0].scatter(x_0, y_0, color = '#A20346', marker = '^', s= 10, label = 'Topic 0')
#axes[0].errorbar(x_0, y_0, yerr_0, color='#A20346', fmt='none')
#axes[0].plot(x_0, y_0, linestyle='solid', color='#A20346', alpha=0.5)
axes[0].set_xlabel('Arbitrary Document number', fontsize=10)
axes[0].set_ylabel('Topic weight', fontsize=10)
#axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[0].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[0].minorticks_off()
axes[0].set_title('(a)')
legend = axes[0].legend(loc='upper left', framealpha=1, frameon=True, edgecolor = 'black')
legend.get_frame().set_linewidth(0.2)


# Plot the second subplot in the middle
axes[1].scatter(x_1, y_1, color = '#004E7E', marker = 'D', s= 10, label = 'Topic 1')
#axes[1].errorbar(x_1, y_1, yerr_1, color='#004E7E', fmt='none')
#axes[1].plot(x_1, y_1, linestyle='solid', color='#004E7E', alpha=0.5)
axes[1].set_xlabel('Arbitrary Document number', fontsize=10)
axes[1].set_ylabel('Topic weight', fontsize=10)
#axes[1].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[1].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[1].minorticks_off()
axes[1].set_title('(b)')
legend = axes[1].legend(loc='upper right', framealpha=1, frameon=True, edgecolor = 'black')
legend.get_frame().set_linewidth(0.2)
filepath = 'Final-graphs-LDA/Y2_sorted_topic_weights'
plt.savefig(filepath, dpi = 1000)

# %%
# x = np.linspace(0,1,1)
# #plt.figure(figsize=(5, 5))
# #plt.vlines(x=93, ymin=0, ymax=len(x), colors='green', lw=1, label='partition')
# plt.scatter(index, sorted_topic_0_y2 , color = '#A20346', label='Topic_0 - Year 1',  marker= '^', s = 6)
# plt.scatter(index, topic_1_y2 ,  color = '#004E7E', label='Topic_1 - Year 2',  marker= 's', s = 6)
# plt.xlabel("Document number")
# plt.ylabel("Topic weight")
# plt.legend( prop = {'size' : 7})
# plt.title('Weights of %d in all documents - YEAR1' % num_topics)
# # single vline with full ymin and ymax
# #plt.vlines(x=95, ymin=0, ymax=len(x), colors='green', ls=':', lw=2, label='vline_single - full height')
# plt.show()

# %% [markdown]
# ### Below are the heatmap and scatter plots helping us to identify plots specific to this year.

# %% [markdown]
# # YEAR 1&2

# %% [markdown]
# ### Below are the heatmap and scatter plots helping us to identify plots specific to this year.

# %%
topic_0 = []
topic_1 = []
for t in range(178):
    topic_0.append(df_y1y2_weight.iloc[t][5])
    topic_1.append(df_y1y2_weight.iloc[t][6])

x = np.linspace(0,1,1)
#plt.figure(figsize=(5, 5))
#plt.vlines(x=93, ymin=0, ymax=len(x), colors='green', lw=1, label='partition')
plt.scatter(df_y1y2_weight.index, topic_0 , color = '#A20346', label='Year 1 topic ',  marker= '^', s = 6)
plt.scatter(df_y1y2_weight.index, topic_1 ,  color = '#004E7E', label='Year 2 topic ',  marker= 's', s = 6)
plt.xlabel("Arbitrary Document number", fontsize = 10)
plt.ylabel("Topic weight", fontsize = 10)

#plt.title('Weights of %d in all documents - YEAR1' % num_topics)
legend = plt.legend( framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 7})
legend.get_frame().set_linewidth(0.2)

plt.axvspan(0, 96, alpha=0.1, color="#A20346")
plt.axvspan(96, 178, alpha=0.1, color="#004E7E")
# single vline with full ymin and ymax
#plt.vlines(x=95, ymin=0, ymax=len(x), colors='black', lw=1, label='vline_single - full height')

# filepath = 'Final-graphs-LDA/Y1Y2_topic_split'
# plt.savefig(filepath, dpi = 1000)
# plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize= (6,2)) 

x_0 = df_y1y2_weight.index
y_0 = topic_0

x_1 = df_y1y2_weight.index
y_1 = topic_1

# Plot the first subplot on the left
axes[0].scatter(x_0, y_0, color = '#A20346', marker = '^', s= 10, label = 'Year 1 topic')
#axes[0].errorbar(x_0, y_0, yerr_0, color='#A20346', fmt='none')
#axes[0].plot(x_0, y_0, linestyle='solid', color='#A20346', alpha=0.5)
axes[0].set_xlabel('Arbitrary Document number', fontsize=8)
axes[0].annotate('Report no. 96', xy = (96,1), xytext=(96,0.8), arrowprops=dict(arrowstyle='->'), fontsize = 5, c = 'black')
axes[0].set_ylabel('Topic weight', fontsize=8)
#axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[0].axvspan(0, 96, alpha=0.1, color="#A20346")
#axes[0].axvspan(96, 178, alpha=0.1, color="#004E7E")
axes[0].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[0].minorticks_off()
axes[0].set_title('(a)', fontsize = 8)
#plt.title('Weights of %d in all documents - YEAR1' % num_topics)
legend = axes[0].legend( loc='lower left', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 5})
legend.get_frame().set_linewidth(0.2)





# Plot the second subplot in the middle
axes[1].scatter(x_1, y_1, color = '#004E7E', marker = 'D', s= 10, label = 'Year 2 topic')
#axes[1].errorbar(x_1, y_1, yerr_1, color='#004E7E', fmt='none')
#axes[1].plot(x_1, y_1, linestyle='solid', color='#004E7E', alpha=0.5)
axes[1].set_xlabel('Arbitrary Document number', fontsize=8)
axes[1].set_ylabel('Topic weight', fontsize=8)
#axes[1].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[1].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
#axes[1].axvspan(0, 96, alpha=0.1, color="#A20346")
axes[1].axvspan(96, 178, alpha=0.1, color="#004E7E")
axes[1].minorticks_off()
axes[1].set_title('(b)', fontsize = 8)
legend = axes[1].legend( loc='lower right', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 5})
legend.get_frame().set_linewidth(0.2)

filepath = 'Final-graphs-LDA/Y1Y2_topic_split_final'
plt.savefig(filepath, dpi = 1000)
plt.show()

# %% [markdown]
# # YEAR 1 / Year 2 graph together for topic prevelance

# %%
x = np.arange(0,0.5,1)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize= (6,2)) 

# Plot the first subplot on the left - YEAR 1

axes[0].scatter(index1, topic_0_y1 , color = '#A20346', label='Topic 0 ',  marker= '^', s = 6)
axes[0].scatter(index1, topic_1_y1 ,  color = '#004E7E', label='Topic 1 ',  marker= 's', s = 6)
axes[0].set_xlabel('Arbitrary Document number', fontsize=8)
axes[0].set_ylabel('Topic weight', fontsize=8)
#axes[0].vlines(x=36, ymin=0, ymax=len(x), colors='black', lw=1, label = 'Report index: 36')
#axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[0].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[0].minorticks_off()
axes[0].set_title('(a)')
axes[0].annotate('Report no. 36', xy = (36,0.5), xytext=(39,0.9), arrowprops=dict(arrowstyle='->'), fontsize = 5, c = 'black')
#axes[0].legend(prop = {'size' : 5})
axes[0].axvspan(0, 3, alpha=0.1, color="green")
axes[0].axvspan(77, 80, alpha=0.1, color="red")
legend = axes[0].legend(framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 5})
legend.get_frame().set_linewidth(0.2)

# Plot the second subplot in the middle - YEAR 2

axes[1].scatter(index, topic_0_y2 , color = '#A20346', label='Topic 0 ',  marker= '^', s = 6)
axes[1].scatter(index, topic_1_y2 ,  color = '#004E7E', label='Topic 1 ',  marker= 's', s = 6)
#axes[1].text(37, 0.5, 'Report no. 37 ', size=4, c = 'red')
axes[1].annotate('Report no. 37', xy = (37,0.5), xytext=(39,0.9), arrowprops=dict(arrowstyle='->'), fontsize = 5, c = 'black')
axes[1].set_xlabel('Arbitrary Document number', fontsize=8)
axes[1].set_ylabel('Topic weight', fontsize=8)
#axes[1].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
axes[1].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
axes[1].minorticks_off()
axes[1].set_title('(b)')
#axes[1].legend(prop = {'size' : 4})
axes[1].axvspan(0, 3, alpha=0.1, color="green")
axes[1].axvspan(67,70, alpha=0.1, color="red")
legend = axes[1].legend(framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 5})
legend.get_frame().set_linewidth(0.2)
filepath = 'Final-graphs-LDA/Y1_Y2_sorted_topic_overlap'

# %% [markdown]
# # YEAR 1 - Justifying the number of topics used

# %%
# # Plot the second subplot in the middle
#     axes[1].scatter(x_1, y_1, color = '#004E7E', marker = 's', s= 10, label = 'blue')
#     axes[1].errorbar(x_1, y_1, yerr_1, color='#004E7E', fmt='none')
#     axes[1].plot(x_1, y_1, linestyle='solid', color='#004E7E', alpha=0.5)
#     axes[1].set_xlabel('Training ratio', fontsize=10)
#     axes[1].set_ylabel('Accuracy', fontsize=10)
#     axes[1].xaxis.set_ticks(np.arange(0.3, 1.0, 0.1))
#     axes[1].yaxis.set_ticks(np.arange(0.2, 1.0, 0.1))
#     axes[1].minorticks_off()
#     axes[1].set_title('(b)')

# axes[0].scatter(index1, topic_0_y1 , color = '#A20346', label='Topic 0 ',  marker= '^', s = 6)
# axes[0].scatter(index1, topic_1_y1 ,  color = '#004E7E', label='Topic 1 ',  marker= 's', s = 6)
# axes[0].set_xlabel('Arbitrary Document number', fontsize=10)
# axes[0].set_ylabel('Topic weight', fontsize=10)
# axes[0].vlines(x=36, ymin=0, ymax=len(x), colors='black', lw=1, label = 'Report index: 36')
# #axes[0].xaxis.set_ticks(np.arange(0.5, 1.0, 0.1))
# axes[0].yaxis.set_ticks(np.arange(0, 1.1, 0.1))
# axes[0].minorticks_off()
# axes[0].set_title('(a)')
# axes[0].legend(prop = {'size' : 5})
# axes[0].axvspan(0, 3, alpha=0.3, color="green")
# axes[0].axvspan(77, 80, alpha=0.3, color="red")


def gridsearch_plot(df, no_below = None, aggreg_func = 'mean'):
    '''
    Plot the results of a grid search. For each no_below value and each alpha value, plot all coherences by topic number
    aggreg_func - 'mean' or 'median'. Aggregation function for the coherence values on the y-axis
    '''    
    nbs = [None]
    alphas = [None]
    if no_below: 
        df = df[df.no_below == no_below]
    if 'no_below' in df.columns:
        reps = int(len(df)/len(df.no_above.unique())/len(df.no_below.unique())/len(df.num_topics.unique()))
        #reps = len(df[(df.num_topics == df.iloc[0].num_topics) & (df.no_below == df.iloc[0].no_below)])
        nbs = df.no_below.unique()
    else: 
        reps = len(df[(df.num_topics == df.iloc[0].num_topics)])
    if 'alpha' in df.columns:
        reps = int(reps / len(df.alpha.unique()))
        alphas = df.alpha.unique()        
    for nb in nbs:
        from matplotlib.ticker import MaxNLocator
        if nb: df0 = df[df.no_below == nb]
        for alpha in alphas:
            if alpha: df0 = df[df.alpha == alpha]
            x = df0.num_topics.unique()
            y = df0.coherence
            fig, ax1 = plt.subplots()
            # for i in range(reps):
            #     _ = ax1.scatter(x, y[i::reps], c="black");
            if aggreg_func == 'mean':
            	coh_mean = y.groupby(np.arange(len(y))//reps).mean()
            elif aggreg_func == 'median':
            	coh_mean = y.groupby(np.arange(len(y))//reps).median()
            print('Maximum %f at num_topics=%d ' % (max(coh_mean), x[0]+list(coh_mean).index(max(coh_mean))))
            #_ = ax1.plot(x, coh_mean, c="blue", label="mean");
            _ = ax1.plot(x, coh_mean, linestyle='solid', color='#004E7E', alpha=0.5);
            _ = ax1.scatter(x, coh_mean, color = '#004E7E', marker = 's', s= 10, label = 'mean');
            #_ = ax1.errorbar(x, coh_mean, yerr=y.groupby(np.arange(len(y))//reps).std(), fmt='--', capsize = 3, c = "blue")
            _ = ax1.errorbar(x, coh_mean, yerr = y.groupby(np.arange(len(y))//reps).std() , color='#004E7E', fmt='none')
            _ = ax1.set_ylabel("Coherence score");
            _ = ax1.set_xlabel("Number of Topics");
            #_ = ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
            _ = plt.legend(loc="best")
            #_ = plt.title("Coherence score. no_below=%s" % (str(nb)))
            legend = ax1.legend( loc='upper right', framealpha=1, frameon=True, edgecolor = 'black', prop = {'size' : 7})
            legend.get_frame().set_linewidth(0.2)
            if alpha: _ = plt.title("Coherence score. no_below=%s, alpha=%s" % (str(nb), str(alpha)))
            plt.show();
    return x,y

# %%
df_y1_topics_gridsearch = pd.read_pickle('Y1_topic_num_justification.pkl')

# %%
import scienceplots
import matplotlib


plt.style.use(['science', 'ieee','no-latex'])
matplotlib.rc('font', family='times new roman')
x = gridsearch_plot(df_y1_topics_gridsearch)[0]
coh_mean = gridsearch_plot(df_y1_topics_gridsearch)[1]
# Out:
# [1. 2. 3. 4. 5.]
# 0     0.227694
# 1     0.227694
# 2     0.227694
# 3     0.267273
# 4     0.276502
# 5     0.235452
# 6     0.237316
# 7     0.233754
# 8     0.237059
# 9     0.211353
# 10    0.261855
# 11    0.252479
# 12    0.296201
# 13    0.257796
# 14    0.287205
# Name: coherence, dtype: float64

# %% [markdown]
# # YEAR 2 - Justifying the number of topics used

# %%
df_y2_topics_gridsearch = pd.read_pickle('Y2_topic_num_justification.pkl')

# %%
import scienceplots
import matplotlib


plt.style.use(['science', 'ieee','no-latex'])
matplotlib.rc('font', family='times new roman')
gridsearch_plot(df_y2_topics_gridsearch)
# Out:
# Maximum 0.280401 at num_topics=5

# %% [markdown]
# # YEAR 1 & 2 - Justifying the number of topics used

# %%
df_y1y2_topics_gridsearch = pd.read_pickle('Y1Y2_topic_num_justification.pkl')

# %%
import scienceplots
import matplotlib


plt.style.use(['science', 'ieee','no-latex'])
matplotlib.rc('font', family='times new roman')
gridsearch_plot(df_y1y2_topics_gridsearch)
# Out:
# Maximum 0.615973 at num_topics=2
